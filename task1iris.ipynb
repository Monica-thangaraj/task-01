# %% [markdown]
# <a href="https://colab.research.google.com/github/Monica-thangaraj/task-01/blob/main/task1iris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
iris = pd.read_csv('/content/Iris (1).csv')
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris= iris.rename(columns={'SepalLengthCm':'Sepal_Length',
                            'SepalWidthCm':'Sepal_Width',
                            'PetalLengthCm':'Petal_Length',
                            'PetalWidthCm':'Petal_Width'})

# %%
iris.head()
# Out:
#    Id  Sepal_Length  Sepla_Width  Petal_Length  Petal_Width      Species
# 0   1           5.1          3.5           1.4          0.2  Iris-setosa
# 1   2           4.9          3.0           1.4          0.2  Iris-setosa
# 2   3           4.7          3.2           1.3          0.2  Iris-setosa
# 3   4           4.6          3.1           1.5          0.2  Iris-setosa
# 4   5           5.0          3.6           1.4          0.2  Iris-setosa

# %%
iris.isnull().sum()
# Out:
# Id              0
# Sepal_Length    0
# Sepla_Width     0
# Petal_Length    0
# Petal_Width     0
# Species         0
# dtype: int64

# %%
iris['Species'].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
iris.describe()
# Out:
#                Id  Sepal_Length  Sepla_Width  Petal_Length  Petal_Width
# count  150.000000    150.000000   150.000000    150.000000   150.000000
# mean    75.500000      5.843333     3.054000      3.758667     1.198667
# std     43.445368      0.828066     0.433594      1.764420     0.763161
# min      1.000000      4.300000     2.000000      1.000000     0.100000
# 25%     38.250000      5.100000     2.800000      1.600000     0.300000
# 50%     75.500000      5.800000     3.000000      4.350000     1.300000
# 75%    112.750000      6.400000     3.300000      5.100000     1.800000
# max    150.000000      7.900000     4.400000      6.900000     2.500000

# %%
sns.FacetGrid(iris, hue="Species",height=6).map(plt.scatter,"Petal_Length","Sepla_Width").add_legend()

# %%
sns.pairplot(iris[['Sepal_Length','Sepla_Width','Petal_Length','Petal_Width','Species']],hue="Species",diag_kind='kde')

# %%
data=iris.values
X=data[:,0:4]
Y=data[:,5]
print(X.shape)
print(X)
# Out:
# (150, 4)
# [[1 5.1 3.5 1.4]
#  [2 4.9 3.0 1.4]
#  [3 4.7 3.2 1.3]
#  [4 4.6 3.1 1.5]
#  [5 5.0 3.6 1.4]
#  [6 5.4 3.9 1.7]
#  [7 4.6 3.4 1.4]
#  [8 5.0 3.4 1.5]
#  [9 4.4 2.9 1.4]
#  [10 4.9 3.1 1.5]
#  [11 5.4 3.7 1.5]
#  [12 4.8 3.4 1.6]
#  [13 4.8 3.0 1.4]
#  [14 4.3 3.0 1.1]
#  [15 5.8 4.0 1.2]
#  [16 5.7 4.4 1.5]
#  [17 5.4 3.9 1.3]
#  [18 5.1 3.5 1.4]
#  [19 5.7 3.8 1.7]
#  [20 5.1 3.8 1.5]
#  [21 5.4 3.4 1.7]
#  [22 5.1 3.7 1.5]
#  [23 4.6 3.6 1.0]
#  [24 5.1 3.3 1.7]
#  [25 4.8 3.4 1.9]
#  [26 5.0 3.0 1.6]
#  [27 5.0 3.4 1.6]
#  [28 5.2 3.5 1.5]
#  [29 5.2 3.4 1.4]
#  [30 4.7 3.2 1.6]
#  [31 4.8 3.1 1.6]
#  [32 5.4 3.4 1.5]
#  [33 5.2 4.1 1.5]
#  [34 5.5 4.2 1.4]
#  [35 4.9 3.1 1.5]
#  [36 5.0 3.2 1.2]
#  [37 5.5 3.5 1.3]
#  [38 4.9 3.1 1.5]
#  [39 4.4 3.0 1.3]
#  [40 5.1 3.4 1.5]
#  [41 5.0 3.5 1.3]
#  [42 4.5 2.3 1.3]
#  [43 4.4 3.2 1.3]
#  [44 5.0 3.5 1.6]
#  [45 5.1 3.8 1.9]
#  [46 4.8 3.0 1.4]
#  [47 5.1 3.8 1.6]
#  [48 4.6 3.2 1.4]
#  [49 5.3 3.7 1.5]
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2, random_state=42)
model_svc = SVC()
model_svc.fit(X_train,Y_train)
# Out:
# SVC()

# %%
prediction1 = model_svc.predict(X_test)
from sklearn.metrics import accuracy_score
print(accuracy_score(Y_test,prediction1))
# Out:
# 1.0

# %%
flower_mapping = {'iris.setosa':0,'iris.versicolor':1,'iris.virginica':2}
iris['Species']=iris['Species'].map(flower_mapping)

# %%
iris.head()
# Out:
#    Id  Sepal_Length  Sepla_Width  Petal_Length  Petal_Width  Species
# 0   1           5.1          3.5           1.4          0.2      NaN
# 1   2           4.9          3.0           1.4          0.2      NaN
# 2   3           4.7          3.2           1.3          0.2      NaN
# 3   4           4.6          3.1           1.5          0.2      NaN
# 4   5           5.0          3.6           1.4          0.2      NaN

# %%
iris.tail()
# Out:
#       Id  Sepal_Length  Sepla_Width  Petal_Length  Petal_Width  Species
# 145  146           6.7          3.0           5.2          2.3      NaN
# 146  147           6.3          2.5           5.0          1.9      NaN
# 147  148           6.5          3.0           5.2          2.0      NaN
# 148  149           6.2          3.4           5.4          2.3      NaN
# 149  150           5.9          3.0           5.1          1.8      NaN

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(X,Y)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
model.score(X,Y)
# Out:
# 1.0

# %%
expected = Y
predicted = model.predict(X)
predicted
# Out:
# array(['Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
# ...
